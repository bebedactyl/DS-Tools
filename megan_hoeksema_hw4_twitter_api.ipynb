# %% [markdown]
# # Total points 8

# %% [markdown]
# # In  the homework
# - We'll collect climate change related tweet from twitter using REST API
# - Use tweets to populate Pandas DataFrames
# - Perform some elementary pandas operation to check data sanity
#
#
# **Please read**
#
# - https://developer.twitter.com/en/developer-terms/more-on-restricted-use-cases

# %% [markdown]
# Before proceeding with homework.
#
# <font size="6" color='red'> Create new app at https://apps.twitter.com/app/new  (You may have to create twitter account before this) </font>

# %% [markdown]
# [twitter api reference index](https://developer.twitter.com/en/docs/api-reference-index)
#
#
# # POST oauth2/token
# Allows a registered application to obtain an OAuth 2 Bearer Token, which can be used to make API requests on an application's own behalf, without a user context.
# https://developer.twitter.com/en/docs/basics/authentication/api-reference/token

# %% [markdown]
# Once you have create app, click on app details and keys and token tab
#
# <font size="6" color='red'> write API key value for client_key and API secret key value for client_secret in the next cell</font>

# %%
client_key = "FeRS4ffYgWTUxREyWh3fLCyqj"#write your API key
client_secret = "eQlvZY3s3pDKnQPDirmeH3JWWSkLyE3IYbWNYbssULxosPqln1" #write your API secret key

# %%
import requests
import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_endpoint = base_url+'oauth2/token'

auth_headers = { 'Authorization': 'Basic {}'.format(b64_encoded_key),
                'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'}

auth_data = { 'grant_type': 'client_credentials'}

# %% [markdown]
# Let's post to authentication endpoint and get the token to be used in subsequent REST API call

# %%
response = requests.post(auth_endpoint, headers=auth_headers, data=auth_data)
response.status_code
# Out:
# 200

# %%
json_data =  response.json()
json_data
# Out:
# {'token_type': 'bearer',
#  'access_token': 'AAAAAAAAAAAAAAAAAAAAAJSDbgEAAAAAGg9NGAElKSQq0Pd47q0dzePJ6YQ%3Dcxr92dVvuH2AcWnCVjFWGmxIgy9Zoalvcm34xZuw0INqv4cxY5'}

# %%
access_token = json_data['access_token']

# %% [markdown]
# # Let's do some search on climate change
# This is how we got search endpoint
#
# https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
max_tweets=10000
tw_limit=100# we can get only 100 tweet per call with standard search api
tweets = []

# %%
search_headers = {'Authorization': 'Bearer {}'.format(access_token)    
}

parameters = { 'q': 'climate change',
                    'result_type': 'recent',
                'count': 100 }

search_url = base_url+'1.1/search/tweets.json'

response = requests.get(search_url, headers=search_headers, params=parameters)

# %%
climate_tweets = response.json()

# %%
len(climate_tweets['statuses'])
# Out:
# 100

# %%
tweets +=climate_tweets['statuses']

# %%
ids = [tw['id'] for tw in climate_tweets['statuses']]

# %%
min_id = min(ids)

# %%
tw_ids = []
tw_ids+=ids

# %% [markdown]
# As per twitter api documentation we can use
#
# max_id:Returns results with an ID less than (that is, older than) or equal to the specified ID.
#
# to get older tweets

# %% [markdown]
# # Q1 (.5 points) Modify only *parameters* dictionary in the following code so that subsequent call to climate change search returns older tweets with id less than minimum of previous tweets ids.

# %%
for  i in range(max_tweets//tw_limit -1):
    parameters = { 'q': 'climate change',
                    'result_type': 'recent',
                'count': tw_limit,
                  'max_id': min_id
                 }
    print("searching tweets with id  < {}".format(min_id))
    search_url = base_url+'1.1/search/tweets.json'
    response = requests.get(search_url, headers=search_headers, params=parameters)
    climate_tweets = response.json()
    ids = [tw['id'] for tw in climate_tweets['statuses']]
    tw_ids+=ids
    print(i, len(climate_tweets['statuses']))
    min_id = min(ids)
    tweets +=climate_tweets['statuses']
# Out:
# searching tweets with id  < 1521272400075280385
# 0 100
# searching tweets with id  < 1521271470147743754
# 1 100
# searching tweets with id  < 1521270600542527488
# 2 100
# searching tweets with id  < 1521269732594397186
# 3 100
# searching tweets with id  < 1521268798182985728
# 4 100
# searching tweets with id  < 1521267849079455746
# 5 100
# searching tweets with id  < 1521267105970196485
# 6 100
# searching tweets with id  < 1521266185656049667
# 7 100
# searching tweets with id  < 1521265370081861633
# 8 100
# searching tweets with id  < 1521264536120143872
# 9 100
# searching tweets with id  < 1521263665529253894
# 10 100
# searching tweets with id  < 1521262786986262540
# 11 100
# searching tweets with id  < 1521261772438908928
# 12 100
# searching tweets with id  < 1521260779101556736
# 13 100
# searching tweets with id  < 1521259752931872768
# 14 100
# searching tweets with id  < 1521258985218711552
# 15 100
# searching tweets with id  < 1521257940187234304
# 16 100
# searching tweets with id  < 1521256977715843074
# 17 100
# searching tweets with id  < 1521256071565742082
# 18 100
# searching tweets with id  < 1521255223410364416
# 19 100
# searching tweets with id  < 1521254356254740486
# 20 100
# searching tweets with id  < 1521253370664685568
# 21 100
# searching tweets with id  < 1521252514561249282
# 22 100
# searching tweets with id  < 1521251682369298432
# 23 100
# searching tweets with id  < 1521250657960816640
# 24 100
# searching tweets with id  < 1521249854906904576
# 25 100
# searching tweets with id  < 1521248969288220672
# 26 100
# searching tweets with id  < 1521248145384124417
# 27 100
# searching tweets with id  < 1521247365734322176
# 28 100
# searching tweets with id  < 1521246606003105793
# 29 100
# searching tweets with id  < 1521245654596608001
# 30 100
# searching tweets with id  < 1521244617072463872
# 31 100
# searching tweets with id  < 1521243585470894080
# 32 100
# searching tweets with id  < 1521242761302786051
# 33 100
# searching tweets with id  < 1521242001332576256
# 34 100
# searching tweets with id  < 1521241122370031616
# 35 100
# searching tweets with id  < 1521240405412655105
# 36 100
# searching tweets with id  < 1521239479935139840
# 37 100
# searching tweets with id  < 1521238690407718912
# 38 100
# searching tweets with id  < 1521237904734887936
# 39 100
# searching tweets with id  < 1521237211538096128
# 40 100
# searching tweets with id  < 1521236568408662016
# 41 100
# searching tweets with id  < 1521235786691137539
# 42 100
# searching tweets with id  < 1521234904109010946
# 43 100
# searching tweets with id  < 1521234000123432960
# 44 100
# searching tweets with id  < 1521233367454429193
# 45 100
# searching tweets with id  < 1521232660416405505
# 46 100
# searching tweets with id  < 1521231798906195970
# 47 100
# searching tweets with id  < 1521230963014914048
# 48 100
# searching tweets with id  < 1521230219406979077
# 49 100
# searching tweets with id  < 1521229470929141768
# 50 100
# searching tweets with id  < 1521228529408651264
# 51 100
# searching tweets with id  < 1521227583056195584
# 52 100
# searching tweets with id  < 1521226755322695680
# 53 100
# searching tweets with id  < 1521225850846257152
# 54 100
# searching tweets with id  < 1521225075348844544
# 55 100
# searching tweets with id  < 1521224249024954373
# 56 100
# searching tweets with id  < 1521223543991775233
# 57 100
# searching tweets with id  < 1521222708721520640
# 58 100
# searching tweets with id  < 1521222055601004547
# 59 100
# searching tweets with id  < 1521221271496925185
# 60 100
# searching tweets with id  < 1521220446267584515
# 61 100
# searching tweets with id  < 1521219618383278082
# 62 100
# searching tweets with id  < 1521218808538484737
# 63 100
# searching tweets with id  < 1521218082332504065
# 64 100
# searching tweets with id  < 1521217277705732097
# 65 100
# searching tweets with id  < 1521216491076603909
# 66 100
# searching tweets with id  < 1521215331812839424
# 67 100
# searching tweets with id  < 1521214443203530754
# 68 100
# searching tweets with id  < 1521213513594806272
# 69 100
# searching tweets with id  < 1521212556890689536
# 70 100
# searching tweets with id  < 1521211722945683458
# 71 100
# searching tweets with id  < 1521210704967180290
# 72 100
# searching tweets with id  < 1521209911266275328
# 73 100
# searching tweets with id  < 1521208832252612608
# 74 100
# searching tweets with id  < 1521207803775442947
# 75 100
# searching tweets with id  < 1521206913236672514
# 76 100
# searching tweets with id  < 1521206042251698176
# 77 100
# searching tweets with id  < 1521205065125617668
# 78 100
# searching tweets with id  < 1521204199761010689
# 79 100
# searching tweets with id  < 1521203388326703105
# 80 100
# searching tweets with id  < 1521202760322064387
# 81 100
# searching tweets with id  < 1521201888712044544
# 82 100
# searching tweets with id  < 1521200941269229571
# 83 100
# searching tweets with id  < 1521200092065288193
# 84 100
# searching tweets with id  < 1521199144836214787
# 85 100
# searching tweets with id  < 1521198311910350848
# 86 100
# searching tweets with id  < 1521197558411841537
# 87 100
# searching tweets with id  < 1521196693059817472
# 88 100
# searching tweets with id  < 1521195971706687493
# 89 100
# searching tweets with id  < 1521195254019411968
# 90 100
# searching tweets with id  < 1521194571866202112
# 91 100
# searching tweets with id  < 1521193559847694336
# 92 100
# searching tweets with id  < 1521192815396413442
# 93 100
# searching tweets with id  < 1521192091572965379
# 94 100
# searching tweets with id  < 1521191457104838657
# 95 100
# searching tweets with id  < 1521190646090018816
# 96 100
# searching tweets with id  < 1521189826837372928
# 97 100
# searching tweets with id  < 1521189080784064512
# 98 100

# %%
print('Total tweets retrieved= {}'.format(len(tweets)))
# Out:
# Total tweets retrieved= 19900

# %% [markdown]
# # Let's print some tweets

# %%
import pprint #pretty-print” arbitrary Python data structures. Tweets object has hierarchical struture
max_tweet_to_print=4

# %%
pprint.pprint(tweets[0:max_tweet_to_print])
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon May 02 23:38:36 +0000 2022',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 1424821374628114435,
#                                   'id_str': '1424821374628114435',
#                                   'indices': [3, 17],
#                                   'name': 'Mulinzi Jordan',
#                                   'screen_name': 'JordanMulinzi'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1521272976502579201,
#   'id_str': '1521272976502579201',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 655,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Mon May 02 07:04:43 +0000 2022',
#                        'entities': {'hashtags': [],
#                                     'symbols': [],
#                                     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                               'expanded_url': 'https://twitter.com/i/web/status/1521022860608913408',
#                                               'indices': [117, 140],
#                                               'url': 'https://t.co/DbOm2VSFca'}],
#                                     'user_mentions': []},
#                        'favorite_count': 1196,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 1521022860608913408,
#                        'id_str': '1521022860608913408',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'en',
#                        'metadata': {'iso_language_code': 'en',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 655,
#                        'retweeted': False,
#                        'source': '<a href="http://twitter.com/download/iphone" '
#                                  'rel="nofollow">Twitter for iPhone</a>',
#                        'text': '200,000 people are dying of hunger In Garrisa, '
#                                'Kenya. Dead animals by the roadside are a '
#                                'common sight— died in larg… '
#                                'https://t.co/DbOm2VSFca',
#                        'truncated': True,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Mon Aug 09 19:54:52 +0000 2021',
#                                 'default_profile': True,
#                                 'default_profile_image': False,
#                                 'description': '15 year old boy who wants '
#                                                'clean and safe water for every '
#                                                'child in Africa. 📩📩 '
#                                                'mulinzijordan54@gmail.com',
#                                 'entities': {'description': {'urls': []},
#                                              'url': {'urls': [{'display_url': 'gofundme.com/f/mulindwa-cle…',
#                                                                'expanded_url': 'https://www.gofundme.com/f/mulindwa-clean-and-safe-water-project?utm_source=',
#                                                                'indices': [0,
#                                                                            23],
#                                                                'url': 'https://t.co/sgNbr84FSE'}]}},
#                                 'favourites_count': 918,
#                                 'follow_request_sent': None,
#                                 'followers_count': 1320,
#                                 'following': None,
#                                 'friends_count': 78,
#                                 'geo_enabled': False,
#                                 'has_extended_profile': True,
#                                 'id': 1424821374628114435,
#                                 'id_str': '1424821374628114435',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': None,
#                                 'listed_count': 9,
#                                 'location': 'Planet earth',
#                                 'name': 'Mulinzi Jordan',
#                                 'notifications': None,
#                                 'profile_background_color': 'F5F8FA',
#                                 'profile_background_image_url': None,
#                                 'profile_background_image_url_https': None,
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1424821374628114435/1628601022',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/1424821880125546502/LUu73nry_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1424821880125546502/LUu73nry_normal.jpg',
#                                 'profile_link_color': '1DA1F2',
#                                 'profile_sidebar_border_color': 'C0DEED',
#                                 'profile_sidebar_fill_color': 'DDEEF6',
#                                 'profile_text_color': '333333',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'JordanMulinzi',
#                                 'statuses_count': 570,
#                                 'time_zone': None,
#                                 'translator_type': 'none',
#                                 'url': 'https://t.co/sgNbr84FSE',
#                                 'utc_offset': None,
#                                 'verified': False,
#                                 'withheld_in_countries': []}},
#   'source': '<a href="http://twitter.com/download/android" '
#             'rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @JordanMulinzi: 200,000 people are dying of hunger In Garrisa, '
#           'Kenya. Dead animals by the roadside are a common sight— died in '
#           'large num…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sun Dec 20 14:35:44 +0000 2020',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'nothing special to tell',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 1124,
#            'follow_request_sent': None,
#            'followers_count': 7,
#            'following': None,
#            'friends_count': 263,
#            'geo_enabled': False,
#            'has_extended_profile': True,
#            'id': 1340667178333421570,
#            'id_str': '1340667178333421570',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 0,
#            'location': '',
#            'name': 'blackbow',
#            'notifications': None,
#            'profile_background_color': 'F5F8FA',
#            'profile_background_image_url': None,
#            'profile_background_image_url_https': None,
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1340667178333421570/1632252987',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1440399358222946310/wsGMlVw-_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1440399358222946310/wsGMlVw-_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'blackbow__',
#            'statuses_count': 88,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False,
#            'withheld_in_countries': []}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon May 02 23:38:32 +0000 2022',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': [{'id': 107810875,
#                                   'id_str': '107810875',
#                                   'indices': [3, 12],
#                                   'name': 'Alan Schneiderman',
#                                   'screen_name': 'alan_s01'},
#                                  {'id': 237042694,
#                                   'id_str': '237042694',
#                                   'indices': [77, 90],
#                                   'name': 'Barnet Labour Party',
#                                   'screen_name': 'BarnetLabour'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1521272962246184960,
#   'id_str': '1521272962246184960',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 13,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#                        'coordinates': None,
#                        'created_at': 'Mon May 02 09:28:42 +0000 2022',
#                        'entities': {'hashtags': [],
#                                     'media': [{'display_url': 'pic.twitter.com/72VlL5dsoO',
#                                                'expanded_url': 'https://twitter.com/alan_s01/status/1521059094379085825/photo/1',
#                                                'id': 1521059086023933953,
#                                                'id_str': '1521059086023933953',
#                                                'indices': [115, 138],
#                                                'media_url': 'http://pbs.twimg.com/media/FRvjLgjWQAESIyH.jpg',
#                                                'media_url_https': 'https://pbs.twimg.com/media/FRvjLgjWQAESIyH.jpg',
#                                                'sizes': {'large': {'h': 1536,
#                                                                    'resize': 'fit',
#                                                                    'w': 2048},
#                                                          'medium': {'h': 900,
#                                                                     'resize': 'fit',
#                                                                     'w': 1200},
#                                                          'small': {'h': 510,
#                                                                    'resize': 'fit',
#                                                                    'w': 680},
#                                                          'thumb': {'h': 150,
#                                                                    'resize': 'crop',
#                                                                    'w': 150}},
#                                                'type': 'photo',
#                                                'url': 'https://t.co/72VlL5dsoO'}],
#                                     'symbols': [],
#                                     'urls': [],
#                                     'user_mentions': [{'id': 237042694,
#                                                        'id_str': '237042694',
#                                                        'indices': [63, 76],
#                                                        'name': 'Barnet Labour '
#                                                                'Party',
#                                                        'screen_name': 'BarnetLabour'}]},
#                        'extended_entities': {'media': [{'display_url': 'pic.twitter.com/72VlL5dsoO',
#                                                         'expanded_url': 'https://twitter.com/alan_s01/status/1521059094379085825/photo/1',
#                                                         'id': 1521059086023933953,
#                                                         'id_str': '1521059086023933953',
#                                                         'indices': [115, 138],
#                                                         'media_url': 'http://pbs.twimg.com/media/FRvjLgjWQAESIyH.jpg',
#                                                         'media_url_https': 'https://pbs.twimg.com/media/FRvjLgjWQAESIyH.jpg',
#                                                         'sizes': {'large': {'h': 1536,
#                                                                             'resize': 'fit',
#                                                                             'w': 2048},
#                                                                   'medium': {'h': 900,
#                                                                              'resize': 'fit',
#                                                                              'w': 1200},
#                                                                   'small': {'h': 510,
#                                                                             'resize': 'fit',
#                                                                             'w': 680},
#                                                                   'thumb': {'h': 150,
#                                                                             'resize': 'crop',
#                                                                             'w': 150}},
#                                                         'type': 'photo',
#                                                         'url': 'https://t.co/72VlL5dsoO'}]},
#                        'favorite_count': 21,
#                        'favorited': False,
#                        'geo': None,
#                        'id': 1521059094379085825,
#                        'id_str': '1521059094379085825',
#                        'in_reply_to_screen_name': None,
#                        'in_reply_to_status_id': None,
#                        'in_reply_to_status_id_str': None,
#                        'in_reply_to_user_id': None,
#                        'in_reply_to_user_id_str': None,
#                        'is_quote_status': False,
#                        'lang': 'en',
#                        'metadata': {'iso_language_code': 'en',
#                                     'result_type': 'recent'},
#                        'place': None,
#                        'possibly_sensitive': False,
#                        'retweet_count': 13,
#                        'retweeted': False,
#                        'source': '<a '
#                                  'href="http://twitter.com/download/android" '
#                                  'rel="nofollow">Twitter for Android</a>',
#                        'text': 'Barnet Tories have ignored the climate '
#                                'emergency for too long. @BarnetLabour has a '
#                                'plan for real change in Barnet. '
#                                'https://t.co/72VlL5dsoO',
#                        'truncated': False,
#                        'user': {'contributors_enabled': False,
#                                 'created_at': 'Sat Jan 23 20:40:16 +0000 2010',
#                                 'default_profile': True,
#                                 'default_profile_image': False,
#                                 'description': 'Labour councillor for '
#                                                'Woodhouse ward in the London '
#                                                'Borough of Barnet - and '
#                                                'candidate for Cricklewood ward '
#                                                'in May 2022',
#                                 'entities': {'description': {'urls': []}},
#                                 'favourites_count': 1229,
#                                 'follow_request_sent': None,
#                                 'followers_count': 1156,
#                                 'following': None,
#                                 'friends_count': 290,
#                                 'geo_enabled': False,
#                                 'has_extended_profile': False,
#                                 'id': 107810875,
#                                 'id_str': '107810875',
#                                 'is_translation_enabled': False,
#                                 'is_translator': False,
#                                 'lang': None,
#                                 'listed_count': 29,
#                                 'location': 'London',
#                                 'name': 'Alan Schneiderman',
#                                 'notifications': None,
#                                 'profile_background_color': 'C0DEED',
#                                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                 'profile_background_tile': False,
#                                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/107810875/1637165988',
#                                 'profile_image_url': 'http://pbs.twimg.com/profile_images/815116755077070848/mVYlotyN_normal.jpg',
#                                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815116755077070848/mVYlotyN_normal.jpg',
#                                 'profile_link_color': '1DA1F2',
#                                 'profile_sidebar_border_color': 'C0DEED',
#                                 'profile_sidebar_fill_color': 'DDEEF6',
#                                 'profile_text_color': '333333',
#                                 'profile_use_background_image': True,
#                                 'protected': False,
#                                 'screen_name': 'alan_s01',
#                                 'statuses_count': 5576,
#                                 'time_zone': None,
#                                 'translator_type': 'none',
#                                 'url': None,
#                                 'utc_offset': None,
#                                 'verified': False,
#                                 'withheld_in_countries': []}},
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @alan_s01: Barnet Tories have ignored the climate emergency for '
#           'too long. @BarnetLabour has a plan for real change in Barnet. '
#           'https://t.…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Tue May 29 21:55:18 +0000 2012',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'Labour Cllr for East Finchley, London Borough of '
#                           'Barnet. Tweeting in a personal capacity. ❤️or RT '
#                           'does not always mean support. 🇪🇺🇮🇳🇬🇧',
#            'entities': {'description': {'urls': []},
#                         'url': {'urls': [{'display_url': 'barnet.gov.uk',
#                                           'expanded_url': 'http://www.barnet.gov.uk',
#                                           'indices': [0, 23],
#                                           'url': 'https://t.co/zuS1QfqjkP'}]}},
#            'favourites_count': 55808,
#            'follow_request_sent': None,
#            'followers_count': 2856,
#            'following': None,
#            'friends_count': 2182,
#            'geo_enabled': True,
#            'has_extended_profile': True,
#            'id': 594149670,
#            'id_str': '594149670',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 51,
#            'location': 'East Finchley, London',
#            'name': 'Arjun Mittra',
#            'notifications': None,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/594149670/1617207511',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1215753552754286592/WIiif-1W_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215753552754286592/WIiif-1W_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'ArjunMittra',
#            'statuses_count': 47622,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': 'https://t.co/zuS1QfqjkP',
#            'utc_offset': None,
#            'verified': True,
#            'withheld_in_countries': []}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon May 02 23:38:32 +0000 2022',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                          'expanded_url': 'https://twitter.com/i/web/status/1521272960924983296',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/CkSFgDgSRT'}],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1521272960924983296,
#   'id_str': '1521272960924983296',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Interference stopped my TV from hearing those numbers maybe other '
#           'people too? It’s amazing to me that under threat… '
#           'https://t.co/CkSFgDgSRT',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Sat May 01 00:59:59 +0000 2010',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'In HS they showed us The Bulldozers bulldozing '
#                           'through piles of bodies into mass graves. I never '
#                           'stopped trying to understand how it came to that.',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 19424,
#            'follow_request_sent': None,
#            'followers_count': 298,
#            'following': None,
#            'friends_count': 992,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 138917150,
#            'id_str': '138917150',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 8,
#            'location': '',
#            'name': 'Raina Fortini',
#            'notifications': None,
#            'profile_background_color': 'C0DEED',
#            'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#            'profile_background_tile': False,
#            'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138917150/1513229847',
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/1389807419048570883/PAV_0b5L_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1389807419048570883/PAV_0b5L_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'rainafortini',
#            'statuses_count': 76448,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False,
#            'withheld_in_countries': []}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon May 02 23:38:31 +0000 2022',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'twitter.com/karilake/statu…',
#                          'expanded_url': 'https://twitter.com/karilake/status/1520932669558730752',
#                          'indices': [25, 48],
#                          'url': 'https://t.co/O49rR9MS4p'}],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1521272958924193795,
#   'id_str': '1521272958924193795',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#                     'coordinates': None,
#                     'created_at': 'Mon May 02 01:06:20 +0000 2022',
#                     'entities': {'hashtags': [],
#                                  'symbols': [],
#                                  'urls': [],
#                                  'user_mentions': []},
#                     'favorite_count': 64261,
#                     'favorited': False,
#                     'geo': None,
#                     'id': 1520932669558730752,
#                     'id_str': '1520932669558730752',
#                     'in_reply_to_screen_name': None,
#                     'in_reply_to_status_id': None,
#                     'in_reply_to_status_id_str': None,
#                     'in_reply_to_user_id': None,
#                     'in_reply_to_user_id_str': None,
#                     'is_quote_status': False,
#                     'lang': 'en',
#                     'metadata': {'iso_language_code': 'en',
#                                  'result_type': 'recent'},
#                     'place': None,
#                     'retweet_count': 10186,
#                     'retweeted': False,
#                     'source': '<a href="http://twitter.com/download/iphone" '
#                               'rel="nofollow">Twitter for iPhone</a>',
#                     'text': 'A child’s gender is determined by God at '
#                             'conception, NOT by some Woke Teacher in the 3rd '
#                             'grade. This insanity must end.',
#                     'truncated': False,
#                     'user': {'contributors_enabled': False,
#                              'created_at': 'Sat Jan 12 07:47:51 +0000 2013',
#                              'default_profile': False,
#                              'default_profile_image': False,
#                              'description': 'Official Twitter Account for '
#                                             'Trump-Endorsed Candidate for '
#                                             'Arizona Governor. Text KARI to '
#                                             '70789. Find me on TRUTH Social at '
#                                             'karilake & FB at TheKariLake.',
#                              'entities': {'description': {'urls': []},
#                                           'url': {'urls': [{'display_url': 'KariLake.com',
#                                                             'expanded_url': 'http://KariLake.com',
#                                                             'indices': [0, 23],
#                                                             'url': 'https://t.co/EmzgORJKeQ'}]}},
#                              'favourites_count': 20839,
#                              'follow_request_sent': None,
#                              'followers_count': 199388,
#                              'following': None,
#                              'friends_count': 1275,
#                              'geo_enabled': True,
#                              'has_extended_profile': True,
#                              'id': 1082197856,
#                              'id_str': '1082197856',
#                              'is_translation_enabled': False,
#                              'is_translator': False,
#                              'lang': None,
#                              'listed_count': 478,
#                              'location': 'Iowa, Phoenix & Pine, AZ ',
#                              'name': 'Kari Lake for AZ Governor',
#                              'notifications': None,
#                              'profile_background_color': '000000',
#                              'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#                              'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#                              'profile_background_tile': False,
#                              'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1082197856/1643184839',
#                              'profile_image_url': 'http://pbs.twimg.com/profile_images/1483357826051284992/McKWxaZ6_normal.jpg',
#                              'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1483357826051284992/McKWxaZ6_normal.jpg',
#                              'profile_link_color': '0084B4',
#                              'profile_sidebar_border_color': '000000',
#                              'profile_sidebar_fill_color': '000000',
#                              'profile_text_color': '000000',
#                              'profile_use_background_image': False,
#                              'protected': False,
#                              'screen_name': 'KariLake',
#                              'statuses_count': 19724,
#                              'time_zone': None,
#                              'translator_type': 'none',
#                              'url': 'https://t.co/EmzgORJKeQ',
#                              'utc_offset': None,
#                              'verified': True,
#                              'withheld_in_countries': []}},
#   'quoted_status_id': 1520932669558730752,
#   'quoted_status_id_str': '1520932669558730752',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" '
#             'rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Focus on climate change. https://t.co/O49rR9MS4p',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Thu Feb 09 18:53:47 +0000 2017',
#            'default_profile': True,
#            'default_profile_image': False,
#            'description': 'We great again yet?',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 8031,
#            'follow_request_sent': None,
#            'followers_count': 114,
#            'following': None,
#            'friends_count': 782,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 829765252635955200,
#            'id_str': '829765252635955200',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': None,
#            'listed_count': 0,
#            'location': '',
#            'name': 'Lisa Smithson',
#            'notifications': None,
#            'profile_background_color': 'F5F8FA',
#            'profile_background_image_url': None,
#            'profile_background_image_url_https': None,
#            'profile_background_tile': False,
#            'profile_image_url': 'http://pbs.twimg.com/profile_images/829766196979326976/xaV2_KJA_normal.jpg',
#            'profile_image_url_https': 'https://pbs.twimg.com/profile_images/829766196979326976/xaV2_KJA_normal.jpg',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'superistgurl1',
#            'statuses_count': 15169,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False,
#            'withheld_in_countries': []}}]

# %% [markdown]
# Link to understand [tweet-object](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object)
#
# Let'see some tweets

# %%
for status in tweets[0:max_tweet_to_print]:
    print(status['text'] + '\n')
# Out:
# RT @JordanMulinzi: 200,000 people are dying of hunger In Garrisa, Kenya. Dead animals by the roadside are a common sight— died in large num…
#
# RT @alan_s01: Barnet Tories have ignored the climate emergency for too long. @BarnetLabour has a plan for real change in Barnet. https://t.…
#
# Interference stopped my TV from hearing those numbers maybe other people too? It’s amazing to me that under threat… https://t.co/CkSFgDgSRT
#
# Focus on climate change. https://t.co/O49rR9MS4p

# %% [markdown]
# # Pandas DataFrame for storing tweet feed
#
# Create following date frame for storing tweets
#
# - **climate_feed_df** DataFrame for storing tweet
# - **user_df** DataFrame for storing user detail
# - **retweeted_status_df** for storing original tweet

# %% [markdown]
# # Printing keys in tweets

# %%
print(tweets[1].keys())
print(len(tweets[1].keys()))
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])
# 25

# %%
import pandas as pd

# %% [markdown]
# # Generators for building DataFrames

# %% [markdown]
# # Q2 (2 point) Complete following   python generator *tweet_generator*. Generator yield modified tweet .
# For each tweet in tweets
# - Replace **user** attribute with **user_id** and value with **tweet['user']['id']** value.
# - Replace **retweeted_status** attribute with **retweeted_status_id** and value with **tweet['retweeted_status']['id']** value.
# - Keep other attributes in the tweet as such.

# %%
def tweet_generator(tweets):
    for tweet in tweets:
        modified_tweet= tweet.copy()
        
        #Write your code here
        modified_tweet['user_id'] = tweet['user']['id']
        del modified_tweet['user']
        if 'retweeted_status' in tweet.keys():
            modified_tweet['retweeted_status_id'] = tweet['retweeted_status']['id']
            del modified_tweet['retweeted_status']
        else:
            modified_tweet['retweeted_status_id'] = None
  
        yield modified_tweet

# %%
# Checking  generator output
list(tweet_generator(tweets[0:2]))
# Out:
# [{'created_at': 'Mon May 02 23:38:36 +0000 2022',
#   'id': 1521272976502579201,
#   'id_str': '1521272976502579201',
#   'text': 'RT @JordanMulinzi: 200,000 people are dying of hunger In Garrisa, Kenya. Dead animals by the roadside are a common sight— died in large num…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'JordanMulinzi',
#      'name': 'Mulinzi Jordan',
#      'id': 1424821374628114435,
#      'id_str': '1424821374628114435',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 655,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en',
#   'user_id': 1340667178333421570,
#   'retweeted_status_id': 1521022860608913408},
#  {'created_at': 'Mon May 02 23:38:32 +0000 2022',
#   'id': 1521272962246184960,
#   'id_str': '1521272962246184960',
#   'text': 'RT @alan_s01: Barnet Tories have ignored the climate emergency for too long. @BarnetLabour has a plan for real change in Barnet. https://t.…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'alan_s01',
#      'name': 'Alan Schneiderman',
#      'id': 107810875,
#      'id_str': '107810875',
#      'indices': [3, 12]},
#     {'screen_name': 'BarnetLabour',
#      'name': 'Barnet Labour Party',
#      'id': 237042694,
#      'id_str': '237042694',
#      'indices': [77, 90]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 13,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en',
#   'user_id': 594149670,
#   'retweeted_status_id': 1521059094379085825}]

# %%
climate_feed_df = pd.DataFrame(tweet_generator(tweets))

# %%
climate_feed_df
# Out:
#                            created_at                   id  \
# 0      Mon May 02 23:38:36 +0000 2022  1521272976502579201
# 1      Mon May 02 23:38:32 +0000 2022  1521272962246184960
# 2      Mon May 02 23:38:32 +0000 2022  1521272960924983296
# 3      Mon May 02 23:38:31 +0000 2022  1521272958924193795
# 4      Mon May 02 23:38:27 +0000 2022  1521272938510491648
# ...                               ...                  ...
# 19895  Mon May 02 18:02:16 +0000 2022  1521188338014773249
# 19896  Mon May 02 18:02:16 +0000 2022  1521188334885875712
# 19897  Mon May 02 18:02:15 +0000 2022  1521188334378311681
# 19898  Mon May 02 18:02:15 +0000 2022  1521188332968898562
# 19899  Mon May 02 18:02:14 +0000 2022  1521188330074955777
#
#                     id_str                                               text  \
# 0      1521272976502579201  RT @JordanMulinzi: 200,000 people are dying of...
# 1      1521272962246184960  RT @alan_s01: Barnet Tories have ignored the c...
# 2      1521272960924983296  Interference stopped my TV from hearing those ...
# 3      1521272958924193795   Focus on climate change. https://t.co/O49rR9MS4p
# 4      1521272938510491648  RT @ProfStrachan: The world is 'perilously clo...
# ...                    ...                                                ...
# 19895  1521188338014773249  RT @TIME: The Ukraine food price crisis is jus...
# 19896  1521188334885875712  @kucoincom @aurigami_PLY Join the elders and h...
# 19897  1521188334378311681  RT @sunlorrie: If the government can't do anyt...
# 19898  1521188332968898562                            https://t.co/KYWnpSPmc7
# 19899  1521188330074955777  RT @HfdsCouncil: Looking for a career change t...
#
#        truncated                                           entities  \
# 0          False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1          False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           True  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3          False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4          False  {'hashtags': [{'text': 'ClimateChange', 'indic...
# ...          ...                                                ...
# 19895      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 19896       True  {'hashtags': [{'text': 'frzss', 'indices': [74...
# 19897      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 19898      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 19899      False  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 19895  {'iso_language_code': 'en', 'result_type': 're...
# 19896  {'iso_language_code': 'en', 'result_type': 're...
# 19897  {'iso_language_code': 'en', 'result_type': 're...
# 19898  {'iso_language_code': 'und', 'result_type': 'r...
# 19899  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/android" ...
# 1      <a href="http://twitter.com/download/iphone" r...
# 2      <a href="http://twitter.com/download/iphone" r...
# 3      <a href="http://twitter.com/download/iphone" r...
# 4      <a href="http://twitter.com/download/iphone" r...
# ...                                                  ...
# 19895  <a href="http://twitter.com/download/iphone" r...
# 19896  <a href="http://twitter.com/download/android" ...
# 19897  <a href="https://mobile.twitter.com" rel="nofo...
# 19898  <a href="http://twitter.com/download/android" ...
# 19899  <a href="http://twitter.com/download/iphone" r...
#
#        in_reply_to_status_id in_reply_to_status_id_str  ...  retweeted lang  \
# 0                        NaN                      None  ...      False   en
# 1                        NaN                      None  ...      False   en
# 2                        NaN                      None  ...      False   en
# 3                        NaN                      None  ...      False   en
# 4                        NaN                      None  ...      False   en
# ...                      ...                       ...  ...        ...  ...
# 19895                    NaN                      None  ...      False   en
# 19896           1.521165e+18       1521165116007460878  ...      False   en
# 19897                    NaN                      None  ...      False   en
# 19898                    NaN                      None  ...      False  und
# 19899                    NaN                      None  ...      False   en
#
#                    user_id retweeted_status_id possibly_sensitive  \
# 0      1340667178333421570        1.521023e+18                NaN
# 1                594149670        1.521059e+18                NaN
# 2                138917150                 NaN              False
# 3       829765252635955200                 NaN              False
# 4      1487635480359276547        1.520858e+18                NaN
# ...                    ...                 ...                ...
# 19895           2904173352        1.521030e+18               True
# 19896  1344531068989435904                 NaN                NaN
# 19897  1118221659780059137        1.521080e+18                NaN
# 19898           1961970000                 NaN              False
# 19899           3308232521        1.520811e+18                NaN
#
#       quoted_status_id quoted_status_id_str  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3         1.520933e+18  1520932669558730752
# 4                  NaN                  NaN
# ...                ...                  ...
# 19895              NaN                  NaN
# 19896              NaN                  NaN
# 19897              NaN                  NaN
# 19898              NaN                  NaN
# 19899              NaN                  NaN
#
#                                            quoted_status  extended_entities  \
# 0                                                    NaN                NaN
# 1                                                    NaN                NaN
# 2                                                    NaN                NaN
# 3      {'created_at': 'Mon May 02 01:06:20 +0000 2022...                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 19895                                                NaN                NaN
# 19896                                                NaN                NaN
# 19897                                                NaN                NaN
# 19898                                                NaN                NaN
# 19899                                                NaN                NaN
#
#        withheld_in_countries
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 19895                    NaN
# 19896                    NaN
# 19897                    NaN
# 19898                    NaN
# 19899                    NaN
#
# [19900 rows x 31 columns]

# %% [markdown]
# # Q3(1 points) List datatype using climate_feed_df. Describe which attributes doesn't have right data types. What should be correct datatype.

# %%
# write code here datatype listing
climate_feed_df.dtypes
# Out:
# created_at                    object
# id                             int64
# id_str                        object
# text                          object
# truncated                       bool
# entities                      object
# metadata                      object
# source                        object
# in_reply_to_status_id        float64
# in_reply_to_status_id_str     object
# in_reply_to_user_id          float64
# in_reply_to_user_id_str       object
# in_reply_to_screen_name       object
# geo                           object
# coordinates                   object
# place                         object
# contributors                  object
# is_quote_status                 bool
# retweet_count                  int64
# favorite_count                 int64
# favorited                       bool
# retweeted                       bool
# lang                          object
# user_id                        int64
# retweeted_status_id          float64
# possibly_sensitive            object
# quoted_status_id             float64
# quoted_status_id_str          object
# quoted_status                 object
# extended_entities             object
# withheld_in_countries         object
# dtype: object

# %% [markdown]
# # write columns with wrong datatype and mention correct data type too.
#
# *double click this cell to edit*

# %% [markdown]
# # Q4 (1.5 point) Complete following tweet_user_generator. Generator should yield only *user* value from a tweet

# %%
def tweet_user_generator(tweets):
    for tweet in tweets:
        yield tweet['user']

# %%
user_df = pd.DataFrame(tweet_user_generator(tweets))

# %%
user_df
# Out:
#                         id               id_str  \
# 0      1340667178333421570  1340667178333421570
# 1                594149670            594149670
# 2                138917150            138917150
# 3       829765252635955200   829765252635955200
# 4      1487635480359276547  1487635480359276547
# ...                    ...                  ...
# 19895           2904173352           2904173352
# 19896  1344531068989435904  1344531068989435904
# 19897  1118221659780059137  1118221659780059137
# 19898           1961970000           1961970000
# 19899           3308232521           3308232521
#
#                                   name    screen_name               location  \
# 0                             blackbow     blackbow__
# 1                         Arjun Mittra    ArjunMittra  East Finchley, London
# 2                        Raina Fortini   rainafortini
# 3                        Lisa Smithson  superistgurl1
# 4                                chia🌱   Chia79408636        http://chia.net
# ...                                ...            ...                    ...
# 19895                             Tomy       tomy2875       Puerto Rico, USA
# 19896                         @mnasiri     mnasiri034
# 19897                      stevanage99    stevanage99       anywhere, Canada
# 19898                        Chris Eve        CJE1946
# 19899  Herefordshire Means Business 💙💛    HfdMeansBiz          Herefordshire
#
#                                              description  \
# 0                                nothing special to tell
# 1      Labour Cllr for East Finchley, London Borough ...
# 2      In HS they showed us The Bulldozers bulldozing...
# 3                                    We great again yet?
# 4                                https://t.co/IlVDltHKHL
# ...                                                  ...
# 19895
# 19896                   ‏زندگی دو روز لعنت به هر دو روزش
# 19897  Intellectual of the highest order; a consummat...
# 19898
# 19899  Herefordshire Means Business mission is to con...
#
#                            url  \
# 0                         None
# 1      https://t.co/zuS1QfqjkP
# 2                         None
# 3                         None
# 4      https://t.co/gkSUVvWYIh
# ...                        ...
# 19895                     None
# 19896                     None
# 19897                     None
# 19898                     None
# 19899  https://t.co/Ft3EwSkVZd
#
#                                                 entities  protected  \
# 0                          {'description': {'urls': []}}      False
# 1      {'url': {'urls': [{'url': 'https://t.co/zuS1Qf...      False
# 2                          {'description': {'urls': []}}      False
# 3                          {'description': {'urls': []}}      False
# 4      {'url': {'urls': [{'url': 'https://t.co/gkSUVv...      False
# ...                                                  ...        ...
# 19895                      {'description': {'urls': []}}      False
# 19896                      {'description': {'urls': []}}      False
# 19897                      {'description': {'urls': []}}      False
# 19898                      {'description': {'urls': []}}      False
# 19899  {'url': {'urls': [{'url': 'https://t.co/Ft3EwS...      False
#
#        followers_count  ...  profile_text_color  profile_use_background_image  \
# 0                    7  ...              333333                          True
# 1                 2856  ...              333333                          True
# 2                  298  ...              333333                          True
# 3                  114  ...              333333                          True
# 4                  427  ...              333333                          True
# ...                ...  ...                 ...                           ...
# 19895              856  ...              333333                          True
# 19896               21  ...              333333                          True
# 19897               78  ...              333333                          True
# 19898              330  ...              333333                          True
# 19899             4167  ...              000000                         False
#
#       has_extended_profile  default_profile default_profile_image following  \
# 0                     True             True                 False      None
# 1                     True             True                 False      None
# 2                    False             True                 False      None
# 3                    False             True                 False      None
# 4                     True             True                 False      None
# ...                    ...              ...                   ...       ...
# 19895                 True             True                 False      None
# 19896                 True             True                 False      None
# 19897                 True             True                  True      None
# 19898                False             True                 False      None
# 19899                False            False                 False      None
#
#        follow_request_sent  notifications  translator_type  \
# 0                     None           None             none
# 1                     None           None             none
# 2                     None           None             none
# 3                     None           None             none
# 4                     None           None             none
# ...                    ...            ...              ...
# 19895                 None           None             none
# 19896                 None           None             none
# 19897                 None           None             none
# 19898                 None           None             none
# 19899                 None           None             none
#
#       withheld_in_countries
# 0                        []
# 1                        []
# 2                        []
# 3                        []
# 4                        []
# ...                     ...
# 19895                    []
# 19896                    []
# 19897                    []
# 19898                    []
# 19899                    []
#
# [19900 rows x 43 columns]

# %% [markdown]
# # Q5(1 point) List datatype of columns using user_df. Describe which attributes doesn't have right data types. What should be correct datatype.

# %%
# write code here for datatype listing
user_df.dtypes
# Out:
# id                                     int64
# id_str                                object
# name                                  object
# screen_name                           object
# location                              object
# description                           object
# url                                   object
# entities                              object
# protected                               bool
# followers_count                        int64
# friends_count                          int64
# listed_count                           int64
# created_at                            object
# favourites_count                       int64
# utc_offset                            object
# time_zone                             object
# geo_enabled                             bool
# verified                                bool
# statuses_count                         int64
# lang                                  object
# contributors_enabled                    bool
# is_translator                           bool
# is_translation_enabled                  bool
# profile_background_color              object
# profile_background_image_url          object
# profile_background_image_url_https    object
# profile_background_tile                 bool
# profile_image_url                     object
# profile_image_url_https               object
# profile_banner_url                    object
# profile_link_color                    object
# profile_sidebar_border_color          object
# profile_sidebar_fill_color            object
# profile_text_color                    object
# profile_use_background_image            bool
# has_extended_profile                    bool
# default_profile                         bool
# default_profile_image                   bool
# following                             object
# follow_request_sent                   object
# notifications                         object
# translator_type                       object
# withheld_in_countries                 object
# dtype: object

# %% [markdown]
# # write columns with wrong datatype and mention correct data type too.
#
# *double click this cell to edit*

# %% [markdown]
# # Q6 (1 point) Complete following retweeted_status_generator. Generator should yield dictionary of retweeted_status value from each tweet. If a tweet doesn't have this key return empty dictionary.

# %%
def retweeted_status_generator(tweets):
    for tweet in tweets:
        if 'retweeted_status' in tweet.keys():
            yield tweet['retweeted_status']
        yield {}

# %%
retweeted_status_df = pd.DataFrame(retweeted_status_generator(tweets))

# %%
retweeted_status_df
# Out:
#                            created_at            id               id_str  \
# 0      Mon May 02 07:04:43 +0000 2022  1.521023e+18  1521022860608913408
# 1                                 NaN           NaN                  NaN
# 2      Mon May 02 09:28:42 +0000 2022  1.521059e+18  1521059094379085825
# 3                                 NaN           NaN                  NaN
# 4                                 NaN           NaN                  NaN
# ...                               ...           ...                  ...
# 33007  Mon May 02 10:49:51 +0000 2022  1.521080e+18  1521079513953746946
# 33008                             NaN           NaN                  NaN
# 33009                             NaN           NaN                  NaN
# 33010  Sun May 01 17:01:08 +0000 2022  1.520811e+18  1520810563344994306
# 33011                             NaN           NaN                  NaN
#
#                                                     text truncated  \
# 0      200,000 people are dying of hunger In Garrisa,...      True
# 1                                                    NaN       NaN
# 2      Barnet Tories have ignored the climate emergen...     False
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
# ...                                                  ...       ...
# 33007  If the government can't do anything about infl...      True
# 33008                                                NaN       NaN
# 33009                                                NaN       NaN
# 33010  Looking for a career change this Spring?\nWe c...      True
# 33011                                                NaN       NaN
#
#                                                 entities  \
# 0      {'hashtags': [], 'symbols': [], 'user_mentions...
# 1                                                    NaN
# 2      {'hashtags': [], 'symbols': [], 'user_mentions...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 33007  {'hashtags': [], 'symbols': [], 'user_mentions...
# 33008                                                NaN
# 33009                                                NaN
# 33010  {'hashtags': [], 'symbols': [], 'user_mentions...
# 33011                                                NaN
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1                                                    NaN
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 33007  {'iso_language_code': 'en', 'result_type': 're...
# 33008                                                NaN
# 33009                                                NaN
# 33010  {'iso_language_code': 'en', 'result_type': 're...
# 33011                                                NaN
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1                                                    NaN
# 2      <a href="http://twitter.com/download/android" ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 33007  <a href="https://mobile.twitter.com" rel="nofo...
# 33008                                                NaN
# 33009                                                NaN
# 33010  <a href="https://orlo.tech" rel="nofollow">Orl...
# 33011                                                NaN
#
#        in_reply_to_status_id in_reply_to_status_id_str  ...  favorite_count  \
# 0                        NaN                      None  ...          1196.0
# 1                        NaN                       NaN  ...             NaN
# 2                        NaN                      None  ...            21.0
# 3                        NaN                       NaN  ...             NaN
# 4                        NaN                       NaN  ...             NaN
# ...                      ...                       ...  ...             ...
# 33007                    NaN                      None  ...          2450.0
# 33008                    NaN                       NaN  ...             NaN
# 33009                    NaN                       NaN  ...             NaN
# 33010                    NaN                      None  ...             1.0
# 33011                    NaN                       NaN  ...             NaN
#
#       favorited retweeted possibly_sensitive  lang  \
# 0         False     False              False    en
# 1           NaN       NaN                NaN   NaN
# 2         False     False              False    en
# 3           NaN       NaN                NaN   NaN
# 4           NaN       NaN                NaN   NaN
# ...         ...       ...                ...   ...
# 33007     False     False              False    en
# 33008       NaN       NaN                NaN   NaN
# 33009       NaN       NaN                NaN   NaN
# 33010     False     False              False    en
# 33011       NaN       NaN                NaN   NaN
#
#                                        extended_entities quoted_status_id  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2      {'media': [{'id': 1521059086023933953, 'id_str...              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 33007                                                NaN              NaN
# 33008                                                NaN              NaN
# 33009                                                NaN              NaN
# 33010                                                NaN              NaN
# 33011                                                NaN              NaN
#
#        quoted_status_id_str quoted_status  scopes
# 0                       NaN           NaN     NaN
# 1                       NaN           NaN     NaN
# 2                       NaN           NaN     NaN
# 3                       NaN           NaN     NaN
# 4                       NaN           NaN     NaN
# ...                     ...           ...     ...
# 33007                   NaN           NaN     NaN
# 33008                   NaN           NaN     NaN
# 33009                   NaN           NaN     NaN
# 33010                   NaN           NaN     NaN
# 33011                   NaN           NaN     NaN
#
# [33012 rows x 30 columns]

# %% [markdown]
# # Q7 (1 point) Write code to find number of rows in retweeted_status_df with all the values NaN. print number of such rows.

# %%
# Write code here
print(retweeted_status_df[retweeted_status_df.isnull().all(axis=1)].shape[0])
retweeted_status_df[retweeted_status_df.isnull().all(axis=1)].head(10)
# Out:
# 19900
#    created_at  id id_str text truncated entities metadata source  \
# 1         NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 3         NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 4         NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 5         NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 7         NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 9         NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 11        NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 13        NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 14        NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
# 16        NaN NaN    NaN  NaN       NaN      NaN      NaN    NaN
#
#     in_reply_to_status_id in_reply_to_status_id_str  ...  favorite_count  \
# 1                     NaN                       NaN  ...             NaN
# 3                     NaN                       NaN  ...             NaN
# 4                     NaN                       NaN  ...             NaN
# 5                     NaN                       NaN  ...             NaN
# 7                     NaN                       NaN  ...             NaN
# 9                     NaN                       NaN  ...             NaN
# 11                    NaN                       NaN  ...             NaN
# 13                    NaN                       NaN  ...             NaN
# 14                    NaN                       NaN  ...             NaN
# 16                    NaN                       NaN  ...             NaN
#
#    favorited retweeted possibly_sensitive  lang  extended_entities  \
# 1        NaN       NaN                NaN   NaN                NaN
# 3        NaN       NaN                NaN   NaN                NaN
# 4        NaN       NaN                NaN   NaN                NaN
# 5        NaN       NaN                NaN   NaN                NaN
# 7        NaN       NaN                NaN   NaN                NaN
# 9        NaN       NaN                NaN   NaN                NaN
# 11       NaN       NaN                NaN   NaN                NaN
# 13       NaN       NaN                NaN   NaN                NaN
# 14       NaN       NaN                NaN   NaN                NaN
# 16       NaN       NaN                NaN   NaN                NaN
#
#    quoted_status_id  quoted_status_id_str quoted_status  scopes
# 1               NaN                   NaN           NaN     NaN
# 3               NaN                   NaN           NaN     NaN
# 4               NaN                   NaN           NaN     NaN
# 5               NaN                   NaN           NaN     NaN
# 7               NaN                   NaN           NaN     NaN
# 9               NaN                   NaN           NaN     NaN
# 11              NaN                   NaN           NaN     NaN
# 13              NaN                   NaN           NaN     NaN
# 14              NaN                   NaN           NaN     NaN
# 16              NaN                   NaN           NaN     NaN
#
# [10 rows x 30 columns]
